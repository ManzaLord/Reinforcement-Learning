# %% [markdown]
# # Anteproyecto - Computación Avanzada
#
# ### Cuanto tiempo dedicarle por semana?
# - Pensaba dedicarle de 2 a 3 horas semanales
#
# ### Cuando pienso terminarlo?
# -
#
# ### Cual es el objetivo?
# -

# %% [markdown]
# ## Ejemplo basico
# En este ejemplo se utiliza un ambiente de pesca basico y un agente.

# %%
from tareaAnteproyecto import Pesca1D
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
#Tasa de crecimiento inicial
r = 1

#Inicializa el ambiente
#env = Pesca1D(r)

#Inicializa el ambiente
env = make_vec_env(lambda: Pesca1D(r), n_envs=1)

#Inicializa el agente
agent = PPO("MlpPolicy", env, verbose=1)
agent.learn(total_timesteps=20000)


#Datos
N = 50
observaciones = np.zeros(N)
rewards = np.zeros(N)
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       8 env = make_vec_env(lambda: Pesca1D(r), n_envs=1)
#       9
#      10 #Inicializa el agente
#      11 agent = PPO("MlpPolicy", env, verbose=1)
# ---> 12 agent.learn(total_timesteps=20000)
#      13
#      14
#      15 #Datos
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
# ...

# %%
#Accion inicial
action = 1

#Reset inicial
pesca.reset()

for i in range(N):

    data = pesca.step(action)

    action = actionFunc(data[0],data[1])

    observaciones[i] = data[0]
    rewards[i] = data[1]

# %%
plt.plot(observaciones)
