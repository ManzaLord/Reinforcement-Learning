# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=4)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_cartpole")

del model # remove to demonstrate saving and loading

model = PPO.load("ppo_cartpole")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    fps             | 8837     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.9        |
# |    ep_rew_mean          | 35.9        |
# | time/                   |             |
# |    fps                  | 1796        |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014481818 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# ...

# %%
# Verificación de Gymnasium y Stable-Baselines3 trabajando juntos

try:
    import gymnasium as gym
    from stable_baselines3 import PPO

    print("✅ Gymnasium y Stable-Baselines3 están instalados correctamente.")

    # Crear entorno de prueba
    env = gym.make("CartPole-v1")

    # Crear modelo PPO
    model = PPO("MlpPolicy", env, verbose=1)

    print("🚀 Entrenando modelo por unas pocas iteraciones...")
    model.learn(total_timesteps=1000)

    print("🎮 Probando el modelo entrenado...")
    obs, _ = env.reset()

    for _ in range(100):
        action, _states = model.predict(obs)
        obs, reward, terminated, truncated, info = env.step(action)

        if terminated or truncated:
            obs, _ = env.reset()

    print("✅ Todo funciona correctamente: ambas librerías operan juntas.")

except ImportError as e:
    print("❌ Error de importación:", e)
    print("Asegúrate de instalar las librerías con:")
    print("pip install gymnasium stable-baselines3")
except Exception as e:
    print("❌ Ocurrió un error durante la ejecución:")
    print(e)
# Out:
# ✅ Gymnasium y Stable-Baselines3 están instalados correctamente.
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Entrenando modelo por unas pocas iteraciones...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | 21.5     |
# | time/              |          |
# |    fps             | 3735     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# 🎮 Probando el modelo entrenado...
# ✅ Todo funciona correctamente: ambas librerías operan juntas.
