# %% [markdown]
# # Proyecto - Computación Avanzada
#
# ## Tema: Aprendizaje de refuerzo en sistemas correlacionados en el tiempo usando redes neuronales

# %%
from pesca_2D_env import Pesca2D
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
#Factor de crecimiento de cada poblacion
r_p = 1
r_d = 0.2

#Factor de ruido agregado al sistema
sigma=0.05

#Poblacion inicial de cada especie
init_B_p = 0.4
init_B_d = 0.7

#Factor T (revisar que hace)
T = 200

#Factor de mortalidad de cada especie
m_p = 0.1 #Probar distintos valores 0.1 - 1 - 1.5
m_d = 0.

#Factor que limita el valor maximo de la poblacion depredadora
C = 1

#Diccionario con los parametros del env
params = { "r_crecimiento": np.array([r_p, r_d]),
           "sigma": sigma,
           "init_B": np.array([init_B_p, init_B_d]),
           "T": T,
           "mortalidad": np.array([m_p, m_d]),
           "C": C,
           "epsilon": 1e-5
}

#Inicializa el ambiente
env = Pesca2D(params)

# %%
#Inicializa el modelo
agent = PPO("MlpPolicy", env, verbose=1)

#Entrena el modelo
agent.learn(total_timesteps=25000)

#Guarda el modelo
agent.save("ppo_pesca_2D")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 26.7     |
# | time/              |          |
# |    fps             | 5673     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 27.3         |
# | time/                   |              |
# |    fps                  | 3084         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0027094362 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.081       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.458        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000199    |
# |    std                  | 0.995        |
# |    value_loss           | 2.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 29.6         |
# | time/                   |              |
# |    fps                  | 2729         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0036278404 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.735        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000511    |
# |    std                  | 0.993        |
# |    value_loss           | 1.92         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 2492        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004212967 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.855       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.978       |
# |    value_loss           | 2.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 30.6        |
# | time/                   |             |
# |    fps                  | 1931        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002315832 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.746       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000688   |
# |    std                  | 0.97        |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 31          |
# | time/                   |             |
# |    fps                  | 1718        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004813264 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00428    |
# |    std                  | 0.962       |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 31.5         |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0017087188 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000213    |
# |    std                  | 0.956        |
# |    value_loss           | 3.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 32.1         |
# | time/                   |              |
# |    fps                  | 1652         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032394459 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.58         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.941        |
# |    value_loss           | 3.83         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 32.5         |
# | time/                   |              |
# |    fps                  | 1566         |
# |    iterations           | 9            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0027783494 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000507    |
# |    std                  | 0.94         |
# |    value_loss           | 4.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 32.6         |
# | time/                   |              |
# |    fps                  | 1509         |
# |    iterations           | 10           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0033210819 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.79         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00208     |
# |    std                  | 0.937        |
# |    value_loss           | 5.64         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 33.9         |
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 11           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0037306647 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 0.921        |
# |    value_loss           | 4.81         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 33.9        |
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004730575 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.37        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000984   |
# |    std                  | 0.923       |
# |    value_loss           | 5.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 34.1         |
# | time/                   |              |
# |    fps                  | 1381         |
# |    iterations           | 13           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0022400012 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000922    |
# |    std                  | 0.924        |
# |    value_loss           | 5.33         |
# ------------------------------------------

# %%
#Carga el modelo (para evitar correr el entrenamiento todas las veces)
agent = PPO.load("ppo_pesca_2D")

# %%
#Cantidad de steps
N = 200

#Reinicia el sistema y obtiene la observación inicial
obs, _ = env.reset()

#Listas para guardar la población y el harvest
presa = np.zeros(N)
depredador = np.zeros(N)
harvest = np.zeros(N)

for i in range(N):
    #El agente define una accion segun la observación
    action, _ = agent.predict(obs, deterministic=True)
    # action = np.array([-1])

    #Calcula un step del environment segun la acción
    obs, reward, terminated, truncated, _ = env.step(action)
    print(obs)

    #Registra la población de cada paso
    presa[i] = env.unnormalize(obs[0])
    depredador[i] = env.unnormalize(obs[1])

    #Registra los rewards de cada paso
    harvest[i] = reward
# Out:
# [ 0.19136699 -0.7735081 ]
# [-0.08365513 -0.7455537 ]
# [ 0.05818962 -0.7244865 ]
# [-0.12760621 -0.68333876]
# [-0.15785162 -0.64136   ]
# [-0.05499499 -0.6019516 ]
# [ 0.07858689 -0.5780389 ]
# [ 0.17394012 -0.5301611 ]
# [-0.33176172 -0.43033224]
# [ 0.05513461 -0.4142218 ]
# [ 0.03674548 -0.34081855]
# [ 0.13746226 -0.28941798]
# [-0.00754291 -0.2548682 ]
# [ 0.35001102 -0.21509118]
# [-0.14432505 -0.13019244]
# [-0.36850664 -0.1325771 ]
# [ 0.18380523 -0.19757147]
# [ 0.32124612 -0.15060796]
# [-0.21563676 -0.10134965]
# [-0.25779462 -0.1304531 ]
# [ 0.01858881 -0.1813558 ]
# [ 0.02656561 -0.15737362]
# [ 0.1286131  -0.12325393]
# [ 0.04108695 -0.11304493]
# [ 0.19961257 -0.08453547]
# [ 0.4172461  -0.05869378]
# [-0.11372583  0.02246938]
# [-0.15163775 -0.03468288]
# [-0.2832519  -0.06427558]
# [-0.05648751 -0.19165255]
# [-0.00496718 -0.15812121]
# [ 0.16974811 -0.12601377]
# [-0.05190456 -0.09725724]
# [ 0.04593333 -0.0922426 ]
# [ 0.0488722  -0.08293361]
# [ 0.08033275 -0.05509995]
# [ 0.13430569 -0.03147447]
# [ 0.03567128 -0.00385854]
# [0.04276342 0.00980525]
# [-0.20630673  0.00978211]
# [-0.1157713   0.02376243]
# [ 0.00363    -0.01194666]
# [-0.11370731 -0.0086949 ]
# [ 0.04233701 -0.02557346]
# [ 0.16641423 -0.00677554]
# [-0.08461407  0.02772965]
# [-0.13091631  0.00716819]
# [ 0.15183806 -0.01159032]
# [0.31023312 0.01209094]
# [-0.12781702  0.05824408]
# [-0.18396193  0.05050989]
# [ 0.10608212 -0.04175594]
# [-0.24138407  0.00592799]
# [ 0.01095053 -0.01465343]
# [-0.08296568 -0.01080638]
# [-0.31712094 -0.02697751]
# [-0.10556424 -0.06759377]
# [-0.18801528 -0.07393751]
# [-0.35538977 -0.1139107 ]
# [-0.2941027  -0.20900857]
# [-0.15514337 -0.22608294]
# [ 0.099097   -0.21625972]
# [-0.3762373  -0.14079902]
# [-0.27146    -0.18785635]
# [ 0.31975   -0.2179361]
# [ 0.2693699  -0.17478788]
# [ 0.1631901 -0.1257551]
# [ 0.02612088 -0.07503828]
# [-0.01376616 -0.04955674]
# [ 0.27599746 -0.0446401 ]
# [-0.03843105  0.02505756]
# [-0.14106213  0.01268576]
# [ 0.09702998 -0.02180584]
# [ 0.02123339 -0.01159656]
# [ 0.37991908 -0.00455665]
# [0.08597667 0.04733969]
# [-0.11866176  0.05762827]
# [0.20064266 0.00847349]
# [0.09353381 0.05306865]
# [0.11635742 0.06459209]
# [-0.21469429  0.07847618]
# [ 2.0667948e-01 -3.5581812e-05]
# [0.07665224 0.04681023]
# [0.21163161 0.05372971]
# [0.0235764  0.10332394]
# [-0.15620531  0.08772993]
# [-0.11562559 -0.0281136 ]
# [-0.20519097 -0.05201423]
# [-0.15901244 -0.09840161]
# [ 0.04495263 -0.1018582 ]
# [-0.05604751 -0.08444089]
# [ 0.0598444  -0.07788174]
# [ 0.36780033 -0.05760403]
# [0.15779324 0.00457771]
# [-0.06421905  0.0299369 ]
# [0.30151245 0.0144357 ]
# [-0.03799212  0.06311958]
# [-0.1264649   0.03881488]
# [-0.22259173 -0.00947979]
# [ 0.10208801 -0.06213105]
# [ 0.23327512 -0.02796216]
# [-0.1211578  -0.00338736]
# [ 0.05404265 -0.03882318]
# [ 0.07145833 -0.0313829 ]
# [-0.1359728  -0.00909092]
# [ 0.08819476 -0.03999224]
# [ 0.08109775 -0.01167156]
# [0.11111751 0.00160781]
# [0.01884068 0.02166586]
# [-0.08836506  0.02141616]
# [-0.13663933 -0.01331067]
# [ 0.09473503 -0.04005925]
# [ 0.29299578 -0.02503315]
# [0.06944025 0.0376087 ]
# [-0.02022982  0.04265144]
# [0.08175268 0.03022457]
# [0.0884992  0.04196328]
# [0.01532076 0.04741722]
# [-0.29075208  0.04246354]
# [ 0.0855673  -0.03345577]
# [ 0.12013425 -0.01371066]
# [0.12286772 0.02297601]
# [0.16698451 0.04525528]
# [-0.4225308   0.08367056]
# [-0.25897324 -0.19596778]
# [-0.07934674 -0.21041586]
# [ 0.1489032  -0.20555653]
# [ 0.144945   -0.19406363]
# [ 0.06026863 -0.17810427]
# [-0.22773321 -0.1420879 ]
# [-0.17010358 -0.17243794]
# [ 0.30382317 -0.17209256]
# [-0.05651779 -0.14217691]
# [ 0.26343143 -0.12869576]
# [-0.02315362 -0.04944124]
# [-0.04902946 -0.04877808]
# [ 0.15959863 -0.04885246]
# [ 0.14969794 -0.01423072]
# [0.00479804 0.03757118]
# [-0.0194418   0.03134158]
# [0.20085275 0.01976175]
# [-0.05983974  0.04995485]
# [-0.34901196  0.00898229]
# [ 0.09844199 -0.08599447]
# [ 0.42016447 -0.04865839]
# [ 0.11340719 -0.03565202]
# [ 0.11098016 -0.00336161]
# [-0.0204545   0.00112127]
# [ 0.06629809 -0.00432683]
# [0.08910657 0.01095911]
# [-0.18389851  0.0304601 ]
# [ 0.11186425 -0.02427434]
# [0.18862873 0.00695944]
# [0.01467313 0.03258979]
# [-0.10975052  0.03194562]
# [-0.17762507  0.01016664]
# [ 0.06180457 -0.03594003]
# [ 0.2762172  -0.01326137]
# [0.12979996 0.05693787]
# [0.169796   0.07005791]
# [0.20471004 0.09996157]
# [0.14409259 0.10681267]
# [-0.22443214  0.11652063]
# [-0.03824989  0.01662907]
# [0.05869382 0.00304237]
# [0.00949206 0.01506835]
# [-0.04721944  0.01428072]
# [0.03479008 0.00214838]
# [0.03949462 0.0089603 ]
# [-0.26983598  0.01722356]
# [-0.1687971  -0.08791503]
# [ 0.06029418 -0.102943  ]
# [ 0.00486212 -0.07488179]
# [-0.13834792 -0.06226916]
# [ 0.06831219 -0.07572459]
# [ 0.01897355 -0.03479546]
# [ 0.07360011 -0.02198412]
# [-0.10343738 -0.00134915]
# [ 0.19513868 -0.01555801]
# [0.07236973 0.04289789]
# [0.04575782 0.05292759]
# [-0.1341468   0.05137862]
# [-0.07038891 -0.00274679]
# [-0.33286902 -0.01384238]
# [-0.00075395 -0.06877152]
# [-0.09625147 -0.04902249]
# [-0.30281806 -0.05914995]
# [-0.2656438  -0.12923177]
# [ 0.00057155 -0.173948  ]
# [ 0.18661028 -0.15791151]
# [ 0.07524706 -0.1001088 ]
# [ 0.4892553  -0.07224479]
# [ 0.19521722 -0.00496554]
# [0.17769471 0.02406363]
# [-0.12430713  0.04225885]
# [0.13286474 0.01480366]
# [0.24220608 0.04538453]
# [-0.10914301  0.10431913]
# [-0.18119194  0.03991506]
# [-0.33837444 -0.00751496]

# %% [markdown]
# ## Resultados: Evolución temporal de la población y del harvest

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Gráfica de población
axs[0].plot(presa)
axs[0].set_xlabel("t")
axs[0].set_ylabel("Presa")
axs[0].set_title("Evolución de la población")
axs[0].grid(True)

# Gráfica de harvest
axs[1].plot(harvest)
axs[1].set_xlabel("t")
axs[1].set_ylabel("Harvest")
axs[1].set_title("Evolución del harvest")
axs[1].grid(True)

plt.tight_layout()
plt.show()

plt.plot(depredador)

# %% [markdown]
# ## Resultados: Población (Biomasa) en función del harvest (mortalidad por pesca)

# %%
#Define la biomasa como un array en el dominio de [0,1]
M = 100
biomass = np.linspace(0, 1, M)

#Crea un array para guardar las acciones del agente
actions = np.zeros(M)

for i in range(M):
    #Normaliza la observacion al formato necesario de -1 a 1
    obs = np.array([-1 + 2*biomass[i]])

    #El agenre da una accion en funcion de la observacion (cantidad de biomasa)
    action, _ = agent.predict(obs,deterministic=True)

    #Desnormaliza y guarda la accion en el dominio de 0 a 1
    actions[i] = (action[0] +1)/2

#Grafica el resultado
plt.plot(biomass, actions)
plt.xlabel("Biomasa")
plt.ylabel("Mortalidad por pesca")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 13
#       9     #Normaliza la observacion al formato necesario de -1 a 1
#      10     obs = np.array([-1 + 2*biomass[i]])
#      11
#      12     #El agenre da una accion en funcion de la observacion (cantidad de biomasa)
# ---> 13     action, _ = agent.predict(obs,deterministic=True)
#      14
#      15     #Desnormaliza y guarda la accion en el dominio de 0 a 1
#      16     actions[i] = (action[0] +1)/2
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/common/base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: np.ndarray | dict[str, np.ndarray],
#    (...)    542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, tuple[np.ndarray, ...] | None]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)    555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)    362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/common/policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/common/utils.py:487, in is_vectorized_observation(observation, observation_space)
#     485 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     486     if isinstance(observation_space, space_type):
# --> 487         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     488 else:
#     489     # for-else happens if no break is called
#     490     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File ~/Proyects/Re-Learning/.venv/lib/python3.12/site-packages/stable_baselines3/common/utils.py:354, in is_vectorized_box_observation(observation, observation_space)
#     352     return True
#     353 else:
# --> 354     raise ValueError(
#     355         f"Error: Unexpected observation shape {observation.shape} for "
#     356         + f"Box environment, please use {observation_space.shape} "
#     357         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     358     )
#
# ValueError: Error: Unexpected observation shape (1,) for Box environment, please use (2,) or (n_env, 2) for the observation shape.

# %% [markdown]
# ### Análisis:
#
# La mortalidad aumenta en función de la biomasa, lo cual tiene sentido, ya que si hay más peces, nos podemos permitir pescar más. Otro detalle importante es que, para poblaciones muy bajas, la pesca se detiene por completo, permitiendo al sistema recuperar biomasa hasta alcanzar una población más estable y evitar la extinción completa de la biomasa.
