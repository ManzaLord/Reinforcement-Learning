# %% [markdown]
# # Proyecto - Computación Avanzada
#
# ## Tema: Aprendizaje de refuerzo en sistemas correlacionados en el tiempo usando redes neuronales

# %%
from pesca_2D_env import Pesca2D
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
#Factor de crecimiento de cada poblacion
r_p = 1
r_d = 0.2

#Factor de ruido agregado al sistema
sigma=0.05

#Poblacion inicial de cada especie
init_B_p = 0.5
init_B_d = 0.2

#Factor T (revisar que hace)
T = 200

#Factor de mortalidad de cada especie
m_p = 0.1 #Probar distintos valores 0.1 - 1 - 1.5
m_d = 0

#Factor que limita el valor maximo de la poblacion depredadora
C = 1

#Diccionario con los parametros del env
params = { "r_crecimiento": np.array([r_p, r_d]),
           "sigma": sigma,
           "init_B": np.array([init_B_p, init_B_d]),
           "T": T,
           "mortalidad": np.array([m_p, m_d]),
           "C": C,
           "epsilon": 1e-5
}

#Inicializa el ambiente
env = Pesca2D(params)

# %%
#Inicializa el modelo
agent = PPO("MlpPolicy", env, verbose=1)

#Entrena el modelo
agent.learn(total_timesteps=25000)

#Guarda el modelo
agent.save("ppo_pesca")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/migue/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    fps             | 581      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 445          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0012440912 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000747    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0284       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 1.04         |
# |    value_loss           | 0.206        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0042007626 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.0219      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.201        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000565    |
# |    std                  | 1.03         |
# |    value_loss           | 0.291        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 427          |
# |    iterations           | 4            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0007855407 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.0298      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.326        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -7.67e-05    |
# |    std                  | 1.05         |
# |    value_loss           | 0.466        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012617831 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.0218      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.467        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.000169     |
# |    std                  | 1.06         |
# |    value_loss           | 0.634        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.000999249 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.0218     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.47        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000595   |
# |    std                  | 1.04        |
# |    value_loss           | 0.849       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 7            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0010555089 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.378        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -4.77e-05    |
# |    std                  | 1.03         |
# |    value_loss           | 0.904        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | 18.2          |
# | time/                   |               |
# |    fps                  | 422           |
# |    iterations           | 8             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00080211135 |
# |    clip_fraction        | 0.000732      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | -0.00584      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.253         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00017      |
# |    std                  | 1.05          |
# |    value_loss           | 1.04          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 9           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.001644025 |
# |    clip_fraction        | 0.000439    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.0041     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.345       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0003     |
# |    std                  | 1.04        |
# |    value_loss           | 1.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 10           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0052386583 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | -0.00238     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.348        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00338     |
# |    std                  | 1.03         |
# |    value_loss           | 1.3          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | 18.2          |
# | time/                   |               |
# |    fps                  | 420           |
# |    iterations           | 11            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00010145339 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.00157      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.503         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 6.94e-05      |
# |    std                  | 1.03          |
# |    value_loss           | 1.26          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 12           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0046836645 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.00109     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.821        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00144     |
# |    std                  | 1.02         |
# |    value_loss           | 1.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 18.2         |
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 13           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0033600233 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -0.000824    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.306        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000986    |
# |    std                  | 1.02         |
# |    value_loss           | 1.32         |
# ------------------------------------------

# %%
#Carga el modelo (para evitar correr el entrenamiento todas las veces)
agent = PPO.load("ppo_pesca")

# %%
#Cantidad de steps
N = 200

#Reinicia el sistema y obtiene la observación inicial
obs, _ = env.reset()

#Listas para guardar la población y el harvest
poblacion = np.zeros(N)
harvest = np.zeros(N)

for i in range(N):
    #El agente define una accion segun la observación
    action, _ = agent.predict(obs, deterministic=True)

    #Calcula un step del environment segun la acción
    obs, reward, terminated, truncated, _ = env.step(action)

    #Registra la población de cada paso
    poblacion[i] = env.unnormalize(obs[0])

    #Registra los rewards de cada paso
    harvest[i] = reward

# %% [markdown]
# ## Resultados: Evolución temporal de la población y del harvest

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Gráfica de población
axs[0].plot(poblacion)
axs[0].set_xlabel("t")
axs[0].set_ylabel("Población")
axs[0].set_title("Evolución de la población")
axs[0].grid(True)

# Gráfica de harvest
axs[1].plot(harvest)
axs[1].set_xlabel("t")
axs[1].set_ylabel("Harvest")
axs[1].set_title("Evolución del harvest")
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Resultados: Población (Biomasa) en función del harvest (mortalidad por pesca)

# %%
#Define la biomasa como un array en el dominio de [0,1]
M = 100
biomass = np.linspace(0, 1, M)

#Crea un array para guardar las acciones del agente
actions = np.zeros(M)

for i in range(M):
    #Normaliza la observacion al formato necesario de -1 a 1
    obs = np.array([-1 + 2*biomass[i]])

    #El agenre da una accion en funcion de la observacion (cantidad de biomasa)
    action, _ = agent.predict(obs,deterministic=True)

    #Desnormaliza y guarda la accion en el dominio de 0 a 1
    actions[i] = (action[0] +1)/2

#Grafica el resultado
plt.plot(biomass, actions)
plt.xlabel("Biomasa")
plt.ylabel("Mortalidad por pesca")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis:
#
# La mortalidad aumenta en función de la biomasa, lo cual tiene sentido, ya que si hay más peces, nos podemos permitir pescar más. Otro detalle importante es que, para poblaciones muy bajas, la pesca se detiene por completo, permitiendo al sistema recuperar biomasa hasta alcanzar una población más estable y evitar la extinción completa de la biomasa.
