# %% [markdown]
# # Proyecto - Computación Avanzada
#
# ## Tema: Aprendizaje de refuerzo en sistemas correlacionados en el tiempo usando redes neuronales

# %%
from pesca_2D_env import Pesca2D
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
#Factor de crecimiento de cada poblacion
r_p = 1
r_d = 0.2

#Factor de ruido agregado al sistema
sigma=0.05

#Poblacion inicial de cada especie
init_B_p = 0.4
init_B_d = 0.7

#Factor T (revisar que hace)
T = 200

#Factor de mortalidad de cada especie
m_p = 0.1 #Probar distintos valores 0.1 - 1 - 1.5
m_d = 0.

#Factor que limita el valor maximo de la poblacion depredadora
C = 1

#Diccionario con los parametros del env
params = { "r_crecimiento": np.array([r_p, r_d]),
           "sigma": sigma,
           "init_B": np.array([init_B_p, init_B_d]),
           "T": T,
           "mortalidad": np.array([m_p, m_d]),
           "C": C,
           "epsilon": 1e-5
}

#Inicializa el ambiente
env = Pesca2D(params)

# %%
#Inicializa el modelo
agent = PPO("MlpPolicy", env, verbose=1)

#Entrena el modelo
agent.learn(total_timesteps=25000)

#Guarda el modelo
agent.save("ppo_pesca_2D")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/migue/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# [0.4 0.7]
# 0.05
# -0.4603978612824606
# [0.4 0.7]
# 0.05
# -1.5187607432793415
# [0.4 0.7]
# 0.05
# -1.814861972971544
# [0.4 0.7]
# 0.05
# -0.5053867757449696
# [0.4 0.7]
# 0.05
# -0.06439526304944436
# [0.4 0.7]
# 0.05
# -0.18564190288319743
# [0.4 0.7]
# 0.05
# -0.27817116983353246
# [0.4 0.7]
# 0.05
# -0.23741179329870596
# [0.4 0.7]
# 0.05
# -1.1042145527868368
# [0.4 0.7]
# 0.05
# 0.40767199287525224
# [0.4 0.7]
# 0.05
# -0.4253232190311655
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 28       |
# | time/              |          |
# |    fps             | 515      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# [0.4 0.7]
# 0.05
# -1.025698096382288
# [0.4 0.7]
# 0.05
# -1.8685973886198137
# [0.4 0.7]
# 0.05
# 0.16919847429563745
# [0.4 0.7]
# 0.05
# -1.9897168476303244
# [0.4 0.7]
# 0.05
# 0.04279576527116947
# [0.4 0.7]
# 0.05
# -0.3701925769666025
# [0.4 0.7]
# 0.05
# 0.8544076176786147
# [0.4 0.7]
# 0.05
# 1.0137557376002564
# [0.4 0.7]
# 0.05
# 0.6287391049538628
# [0.4 0.7]
# 0.05
# -0.7573933954307023
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 28.5         |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0066386657 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0423      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.43         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00423     |
# |    std                  | 1.03         |
# |    value_loss           | 2.15         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# 0.08185775801080808
# [0.4 0.7]
# 0.05
# 0.9045188236676343
# [0.4 0.7]
# 0.05
# -1.5157953744237884
# [0.4 0.7]
# 0.05
# 0.18297325389586347
# [0.4 0.7]
# 0.05
# -2.2549285483370927
# [0.4 0.7]
# 0.05
# -0.42488516447340174
# [0.4 0.7]
# 0.05
# 0.22815663583583246
# [0.4 0.7]
# 0.05
# 0.39694441676151804
# [0.4 0.7]
# 0.05
# -1.2204423482900741
# [0.4 0.7]
# 0.05
# -1.3901824747095886
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 27           |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0030392339 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.43         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.907        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000989    |
# |    std                  | 1.02         |
# |    value_loss           | 2.09         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -1.0856308360080942
# [0.4 0.7]
# 0.05
# 1.275279708834279
# [0.4 0.7]
# 0.05
# -2.222742641702821
# [0.4 0.7]
# 0.05
# 0.9893585085746651
# [0.4 0.7]
# 0.05
# -0.39758152136280067
# [0.4 0.7]
# 0.05
# 1.562697995050944
# [0.4 0.7]
# 0.05
# -0.643316821573613
# [0.4 0.7]
# 0.05
# -0.048851661396827645
# [0.4 0.7]
# 0.05
# 1.5118734179088593
# [0.4 0.7]
# 0.05
# -1.1538843068512894
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0018478532 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.866        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000801    |
# |    std                  | 1.01         |
# |    value_loss           | 2.23         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -0.846539233412
# [0.4 0.7]
# 0.05
# 0.9659458830170904
# [0.4 0.7]
# 0.05
# 0.5852400548266394
# [0.4 0.7]
# 0.05
# 0.10044140627479506
# [0.4 0.7]
# 0.05
# 0.6090833054653945
# [0.4 0.7]
# 0.05
# -2.2280663068560473
# [0.4 0.7]
# 0.05
# -0.37842065020282206
# [0.4 0.7]
# 0.05
# -0.04369727171658514
# [0.4 0.7]
# 0.05
# 0.2548247409052515
# [0.4 0.7]
# 0.05
# -0.49054005169052517
# [0.4 0.7]
# 0.05
# -2.1870794842963734
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 27.7         |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 5            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0023885262 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.595        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.973        |
# |    value_loss           | 3            |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -0.8005095853779949
# [0.4 0.7]
# 0.05
# -1.0489645070231093
# [0.4 0.7]
# 0.05
# -1.5917819211773605
# [0.4 0.7]
# 0.05
# -0.1094868180940829
# [0.4 0.7]
# 0.05
# 0.11724905076404037
# [0.4 0.7]
# 0.05
# 1.7026787046541132
# [0.4 0.7]
# 0.05
# 0.2614996425984221
# [0.4 0.7]
# 0.05
# 0.11189320875557397
# [0.4 0.7]
# 0.05
# -0.7782925838072597
# [0.4 0.7]
# 0.05
# 1.162145665752262
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 28.4        |
# | time/                   |             |
# |    fps                  | 311         |
# |    iterations           | 6           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002055296 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.611       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.966       |
# |    value_loss           | 3.03        |
# -----------------------------------------
# [0.4 0.7]
# 0.05
# -0.3439084771593829
# [0.4 0.7]
# 0.05
# 0.09359166498083381
# [0.4 0.7]
# 0.05
# -0.7126334672579588
# [0.4 0.7]
# 0.05
# 0.5652152374863151
# [0.4 0.7]
# 0.05
# 0.5041903073928643
# [0.4 0.7]
# 0.05
# 0.6646804447921757
# [0.4 0.7]
# 0.05
# 0.1835178289664655
# [0.4 0.7]
# 0.05
# -0.8615479911274914
# [0.4 0.7]
# 0.05
# 1.451291857433383
# [0.4 0.7]
# 0.05
# -1.8651870654858698
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 29.3         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 7            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0033855415 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.949        |
# |    value_loss           | 3.96         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -0.017415987913837253
# [0.4 0.7]
# 0.05
# 2.187283217249496
# [0.4 0.7]
# 0.05
# 1.2397278198097377
# [0.4 0.7]
# 0.05
# -0.9731571898170687
# [0.4 0.7]
# 0.05
# -0.271237633436669
# [0.4 0.7]
# 0.05
# -0.6664316084172012
# [0.4 0.7]
# 0.05
# 1.0263666450283624
# [0.4 0.7]
# 0.05
# 0.8572647216186272
# [0.4 0.7]
# 0.05
# 1.8701706930557684
# [0.4 0.7]
# 0.05
# -1.9522199096263155
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 30.5         |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 8            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0022592773 |
# |    clip_fraction        | 0.00449      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000976    |
# |    std                  | 0.924        |
# |    value_loss           | 4.51         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -0.06839361518737479
# [0.4 0.7]
# 0.05
# 2.066217297437733
# [0.4 0.7]
# 0.05
# 0.22492731814033007
# [0.4 0.7]
# 0.05
# -1.3644642858194687
# [0.4 0.7]
# 0.05
# 0.7562805281060926
# [0.4 0.7]
# 0.05
# -0.9307124915161235
# [0.4 0.7]
# 0.05
# 0.010468470163003495
# [0.4 0.7]
# 0.05
# -0.8840941519590149
# [0.4 0.7]
# 0.05
# -0.15510877019812583
# [0.4 0.7]
# 0.05
# -0.899972066938237
# [0.4 0.7]
# 0.05
# 0.47919515918766126
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 30.8         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 9            |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0025135567 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000629    |
# |    std                  | 0.926        |
# |    value_loss           | 4.72         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# 2.501917716321565
# [0.4 0.7]
# 0.05
# -0.16975460681370955
# [0.4 0.7]
# 0.05
# -0.5641605920850267
# [0.4 0.7]
# 0.05
# 0.20580741499779304
# [0.4 0.7]
# 0.05
# -1.4550491448228853
# [0.4 0.7]
# 0.05
# 0.6650854568007661
# [0.4 0.7]
# 0.05
# -0.6057357507229535
# [0.4 0.7]
# 0.05
# 1.1223182515129466
# [0.4 0.7]
# 0.05
# -0.12244019688385512
# [0.4 0.7]
# 0.05
# -0.24951410720275055
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 30.2         |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 10           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0034401438 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.931        |
# |    value_loss           | 4.78         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# 0.6388794931780712
# [0.4 0.7]
# 0.05
# 0.3957806928433424
# [0.4 0.7]
# 0.05
# 0.5885942439943492
# [0.4 0.7]
# 0.05
# 0.883517063821585
# [0.4 0.7]
# 0.05
# 0.38587291965475357
# [0.4 0.7]
# 0.05
# 0.10182851565257046
# [0.4 0.7]
# 0.05
# 0.13060158652121082
# [0.4 0.7]
# 0.05
# -1.0649565359561513
# [0.4 0.7]
# 0.05
# 1.0638532672081888
# [0.4 0.7]
# 0.05
# -0.15854836656457358
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 31           |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 11           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0010983184 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.915        |
# |    value_loss           | 4.28         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# 0.6359453893892345
# [0.4 0.7]
# 0.05
# -0.8248985625421608
# [0.4 0.7]
# 0.05
# 0.7842626015649713
# [0.4 0.7]
# 0.05
# 1.1739273369743095
# [0.4 0.7]
# 0.05
# 0.8386934206454739
# [0.4 0.7]
# 0.05
# 0.9439394537443788
# [0.4 0.7]
# 0.05
# -0.292566837996031
# [0.4 0.7]
# 0.05
# 0.2893167315678183
# [0.4 0.7]
# 0.05
# -0.25867003374566505
# [0.4 0.7]
# 0.05
# -0.7584131872636342
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 31.7         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 12           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0014050186 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000698    |
# |    std                  | 0.896        |
# |    value_loss           | 4.85         |
# ------------------------------------------
# [0.4 0.7]
# 0.05
# -0.4941588911038589
# [0.4 0.7]
# 0.05
# 0.3205133166915047
# [0.4 0.7]
# 0.05
# 0.21703699184705524
# [0.4 0.7]
# 0.05
# -0.920768280914268
# [0.4 0.7]
# 0.05
# -0.17622379410010167
# [0.4 0.7]
# 0.05
# -0.41546856262921833
# [0.4 0.7]
# 0.05
# 1.301497135827614
# [0.4 0.7]
# 0.05
# 0.8695819394837355
# [0.4 0.7]
# 0.05
# 0.8630141750919372
# [0.4 0.7]
# 0.05
# -1.0086891843280787
# [0.4 0.7]
# 0.05
# 1.4163816137850351
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 32.8        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 13          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003757998 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0015     |
# |    std                  | 0.893       |
# |    value_loss           | 5.18        |
# -----------------------------------------

# %%
#Carga el modelo (para evitar correr el entrenamiento todas las veces)
agent = PPO.load("ppo_pesca_2D")

# %%
#Cantidad de steps
N = 200

#Reinicia el sistema y obtiene la observación inicial
obs, _ = env.reset()

#Listas para guardar la población y el harvest
presa = np.zeros(N)
depredador = np.zeros(N)
harvest = np.zeros(N)

for i in range(N):
    #El agente define una accion segun la observación
    action, _ = agent.predict(obs, deterministic=True)
    # action = np.array([-1])

    #Calcula un step del environment segun la acción
    obs, reward, terminated, truncated, _ = env.step(action)

    #Registra la población de cada paso
    presa[i] = env.unnormalize(obs[0])
    depredador[i] = env.unnormalize(obs[1])

    #Registra los rewards de cada paso
    harvest[i] = reward

# %% [markdown]
# ## Resultados: Evolución temporal de la población y del harvest

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Gráfica de población
axs[0].plot(presa)
axs[0].set_xlabel("t")
axs[0].set_ylabel("Presa")
axs[0].set_title("Evolución de la población")
axs[0].grid(True)

# Gráfica de harvest
axs[1].plot(harvest)
axs[1].set_xlabel("t")
axs[1].set_ylabel("Harvest")
axs[1].set_title("Evolución del harvest")
axs[1].grid(True)

plt.tight_layout()
plt.show()

plt.plot(depredador)

# %% [markdown]
# ## Resultados: Población (Biomasa) en función del harvest (mortalidad por pesca)

# %%
#Define la biomasa como un array en el dominio de [0,1]
M = 100
biomass = np.linspace(0, 1, M)

#Crea un array para guardar las acciones del agente
actions = np.zeros(M)

for i in range(M):
    #Normaliza la observacion al formato necesario de -1 a 1
    obs = np.array([-1 + 2*biomass[i]])

    #El agenre da una accion en funcion de la observacion (cantidad de biomasa)
    action, _ = agent.predict(obs,deterministic=True)

    #Desnormaliza y guarda la accion en el dominio de 0 a 1
    actions[i] = (action[0] +1)/2

#Grafica el resultado
plt.plot(biomass, actions)
plt.xlabel("Biomasa")
plt.ylabel("Mortalidad por pesca")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 13
#      10 obs = np.array([-1 + 2*biomass[i]])
#      12 #El agenre da una accion en funcion de la observacion (cantidad de biomasa)
# ---> 13 action, _ = agent.predict(obs,deterministic=True)
#      15 #Desnormaliza y guarda la accion en el dominio de 0 a 1
#      16 actions[i] = (action[0] +1)/2
#
# File ~/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/base_class.py:557, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     537 def predict(
#     538     self,
#     539     observation: np.ndarray | dict[str, np.ndarray],
#    (...)    542     deterministic: bool = False,
#     543 ) -> tuple[np.ndarray, tuple[np.ndarray, ...] | None]:
#     544     """
#     545     Get the policy action from an observation (and optional hidden state).
#     546     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)    555         (used in recurrent policies)
#     556     """
# --> 557     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)    362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File ~/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File ~/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/utils.py:487, in is_vectorized_observation(observation, observation_space)
#     485 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     486     if isinstance(observation_space, space_type):
# --> 487         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     488 else:
#     489     # for-else happens if no break is called
#     490     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File ~/micromamba/envs/basico/lib/python3.12/site-packages/stable_baselines3/common/utils.py:354, in is_vectorized_box_observation(observation, observation_space)
#     352     return True
#     353 else:
# --> 354     raise ValueError(
#     355         f"Error: Unexpected observation shape {observation.shape} for "
#     356         + f"Box environment, please use {observation_space.shape} "
#     357         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     358     )
#
# ValueError: Error: Unexpected observation shape (1,) for Box environment, please use (2,) or (n_env, 2) for the observation shape.

# %% [markdown]
# ### Análisis:
#
# La mortalidad aumenta en función de la biomasa, lo cual tiene sentido, ya que si hay más peces, nos podemos permitir pescar más. Otro detalle importante es que, para poblaciones muy bajas, la pesca se detiene por completo, permitiendo al sistema recuperar biomasa hasta alcanzar una población más estable y evitar la extinción completa de la biomasa.
